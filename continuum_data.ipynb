# %%
import matplotlib.pylab as plt
import numpy as np
from astropy import units as u
from astropy.io import fits
import aplpy
import matplotlib.patheffects as pe
from astropy.wcs import WCS

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cont = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/data/DraChi.CONT.fits')
cont_data = cont[0].data
cont_header = cont[0].header
cont_header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                  144
# NAXIS2  =                  144
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   1.013391282823E-03
# BMIN    =   6.732167800268E-04
# BPA     =   2.296761894226E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'DraChi  '
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =   6.739415000000E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# PC4_3   =   0.000000000000E+00
# PC1_4   =   0.000000000000E+00
# PC2_4   =   0.000000000000E+00
# PC3_4   =   0.000000000000E+00
# PC4_4   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   3.474318541667E+02
# CDELT1  =  -1.388888888889E-04
# CRPIX1  =   7.300000000000E+01
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =   6.739415000000E+01
# CDELT2  =   1.388888888889E-04
# CRPIX2  =   7.300000000000E+01
# CUNIT2  = 'deg     '
# CTYPE3  = 'FREQ    '
# CRVAL3  =   2.255264159921E+11
# CDELT3  =   3.230013964844E+10
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = 'Hz      '
# CTYPE4  = 'STOKES  '
# CRVAL4  =   1.000000000000E+00
# CDELT4  =   1.000000000000E+00
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = '        '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   2.255264159921E+11 /Rest Frequency (Hz)
# SPECSYS = 'LSRK    '           /Spectral reference frame
# ALTRVAL =  -0.000000000000E+00 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'SMA     '
# OBSERVER= 'SMA     '
# DATE-OBS= '2023-04-25T13:41:14.229173'
# TIMESYS = 'UTC     '
# OBSRA   =   3.474318541667E+02
# OBSDEC  =   6.739415000000E+01
# OBSGEO-X=  -5.462448949395E+06
# OBSGEO-Y=  -2.491969916598E+06
# OBSGEO-Z=   2.164446105480E+06
# INSTRUME= 'SMA     '
# DISTANCE=   0.000000000000E+00
# MPIPROCS=                    1
# CHNCHNKS=                    1
# MEMREQ  =        1.0862947E-03
# MEMAVAIL=        7.9611244E+01
# USEWEIGH=                    F
# DATE    = '2023-07-20T18:29:51.440659' /Date FITS file was written
# ORIGIN  = 'CASA 6.4.1-12 CASAtools:v1.0.0'
# HISTORY CASA START LOGTABLE
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY taskname=tclean
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY version: 6.5.3-28 CASAtools:v1.0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY vis         = "DraChi.redux.cont.ms/"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY selectdata  = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY field       = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY spw         = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY timerange   = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY uvrange     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY antenna     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY scan        = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY observation = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY intent      = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY datacolumn  = "corrected"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY imagename   = "DraChi.2305redux.briggs.im"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY imsize      = 144
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cell        = "0.5arcsec"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY phasecenter = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY stokes      = "I"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY projection  = "SIN"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY startmodel  = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY specmode    = "mfs"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY reffreq     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nchan       = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY start       = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY width       = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY outframe    = "LSRK"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY veltype     = "radio"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restfreq    = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY interpolation = "linear"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY perchanweightdensity = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY gridder     = "standard"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY facets      = 1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY psfphasecenter = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY wprojplanes = 1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY vptable     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY mosweight   = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY aterm       = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY psterm      = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY wbawp       = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY conjbeams   = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cfcache     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY usepointing = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY computepastep = 360.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY rotatepastep = 360.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pointingoffsetsigdev = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pblimit     = 0.2
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY normtype    = "flatnoise"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY deconvolver = "hogbom"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY scales      = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nterms      = 2
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY smallscalebias = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY fusedthreshold = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY largestscale = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restoration = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restoringbeam = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pbcor       = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY outlierfile = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY weighting   = "briggs"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY robust      = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY noise       = "1.0Jy"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY npixels     = 0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY uvtaper     = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY niter       = 1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY gain        = 0.1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY threshold   = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nsigma      = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cycleniter  = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cyclefactor = 1.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY minpsffraction = 0.05
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY maxpsffraction = 0.8
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY interactive = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY fullsummary = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nmajor      = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY usemask     = "user"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY mask        = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pbmask      = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY sidelobethreshold = 3.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY noisethreshold = 5.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY lownoisethreshold = 1.5
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY negativethreshold = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY smoothfactor = 1.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY minbeamfrac = 0.3
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cutthreshold = 0.01
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY growiterations = 75
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY dogrowprune = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY minpercentchange = -1.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY verbose     = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY fastnoise   = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restart     = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY savemodel   = "none"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY calcres     = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY calcpsf     = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY psfcutoff   = 0.35
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY parallel    = False
# HISTORY CASA END LOGTABLE

# %%
print((cont_header['BMAJ']*u.deg).to(u.arcsec))
print((cont_header['BMIN']*u.deg).to(u.arcsec))
print(cont_header['BPA']*u.deg)
# Out:
# 3.6482086181628 arcsec
# 2.42358040809648 arcsec
# 22.96761894226 deg

# %% [markdown]
# ### Get pixel scale

# %%
from astropy import wcs

ww2 = wcs.WCS(cont[0].header)

wcs.utils.proj_plane_pixel_scales(ww2)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# array([1.38888889e-04, 1.38888889e-04, 3.23001396e+10, 1.00000000e+00])

# %% [markdown]
# ### Get rest frequency & wavelength

# %%
rest_frequency = 2.255264159921E+11/1e9*u.GHz
rest_wavelength = rest_frequency.to(u.mm, equivalencies=u.spectral())

print(rest_frequency, rest_wavelength)
# Out:
# 225.5264159921 GHz 1.3293008567586224 mm

# %% [markdown]
# #### There is a problem in aplpy that does not allow to perform some operations (such as recentering or plotting contours) on 4-dimensional cubes that include the stokes and frequency as additional dimensions. I found a hack that should fix this problem here: https://github.com/aplpy/aplpy/issues/423

# %%
def fix_aplpy_fits(aplpy_obj, dropaxis=2):
    """This removes the degenerated dimensions in APLpy 2.X...
    The input must be the object returned by aplpy.FITSFigure().
    `dropaxis` is the index where to start dropping the axis (by default it assumes the 3rd,4th place).
    """
    temp_wcs = aplpy_obj._wcs.dropaxis(dropaxis)
    temp_wcs = temp_wcs.dropaxis(dropaxis)
    aplpy_obj._wcs = temp_wcs

# %%
def figure_layout( fig, c_unit, fontcolor='white', colorbar=True):
    fig.set_nan_color('0.95')
    
    # beam 
    fig.add_beam()
    fig.beam.set(facecolor='white', edgecolor='black', hatch='////////')
    
    # 
    fig.axis_labels.set_font(size=15)
    fig.axis_labels.set_xtext('Right Ascension (ICRS)')
    fig.axis_labels.set_ytext('Declination (ICRS)')
    #fig.axis_labels.set_ypad(pad=-1.5)
    fig.tick_labels.set_yformat('d.ddd')
    fig.tick_labels.set_xformat('d.ddd')

    ## Scale bar
    ang_sep = (12*u.arcsec).to(u.rad)
    fig.add_scalebar(ang_sep)
    fig.scalebar.set_label("$12''$")
    fig.scalebar.set_font(size=22)
    fig.scalebar.set_linewidth(3) 
    fig.scalebar.set_color(fontcolor)
    
    if colorbar:
        fig.add_colorbar()
        fig.colorbar.set_location('right')
        fig.colorbar.set_width(0.1)
        fig.colorbar.set_pad(0.05)
        fig.colorbar.set_axis_label_text(c_unit)
        fig.colorbar.set_label_properties(size=10)
    
    # Ticks
    fig.ticks.set_color(fontcolor)
    fig.ticks.set_tick_direction('in')
    #fig.ticks.set_minor_frequency(4)
    #fig.ticks.set_yspacing(0.006)  # degrees

# %%
color_table='cubehelix'
fig = plt.figure(dpi=150)

f_cont = aplpy.FITSFigure(cont, figure=fig, dimensions=[0,1], slices=[1])
fix_aplpy_fits(f_cont)

vmin, vmax = np.nanpercentile(cont[0].data, [2,98])
f_cont.show_colorscale(cmap=color_table) 

max_em = 0.016 # Jy/beam from CASA
c_levs = np.arange(0.2,1.2,0.2)*max_em

# adopt the default layout
figure_layout( f_cont, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False)

f_cont.show_contour(colors='white', linewidths=2., levels=c_levs)
f_cont.show_contour(colors='black', linewidths=1., levels=c_levs)

# got the coordinates of the center from CASAviewer
f_cont.recenter(347.432,67.3942,width=0.008,height=0.008)

f_cont.add_label(0.8,0.92, '1.3 mm', relative=True, color='white', size=20)


im = plt.imshow(cont[0].data[0][0]*1000, cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('Flux density $(\mathrm{mJy\,beam^{-1}})$', fontsize=10)

fig.savefig('../plots/DraChi_cont_withcontours.pdf', bbox_inches='tight')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.207e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.055e-02 [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
color_table='cubehelix'
fig = plt.figure(dpi=150)

f_cont = aplpy.FITSFigure(cont, figure=fig, dimensions=[0,1], slices=[1])
fix_aplpy_fits(f_cont)

vmin, vmax = np.nanpercentile(cont[0].data, [2,98])
f_cont.show_colorscale(cmap=color_table) 

rms_em = 1.41e-3 # Jy/beam from CASA
c_levs = np.array([3,6,12,24])*rms_em

# adopt the default layout
figure_layout( f_cont, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False)

f_cont.show_contour(colors='white', linewidths=2., levels=c_levs)
f_cont.show_contour(colors='black', linewidths=1., levels=c_levs)

# got the coordinates of the center from CASAviewer
f_cont.recenter(347.432,67.3942,width=0.008,height=0.008)

f_cont.add_label(0.80,0.92, '1.3 mm.', relative=True, color='white', size=20)


im = plt.imshow(cont[0].data[0][0]*1000, cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('Flux density $(\mathrm{mJy\,beam^{-1}})$', fontsize=10)

fig.savefig('../plots/DraChi_cont_withcontours_2.pdf', bbox_inches='tight')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.208e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.046e-02 [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %% [markdown]
# ## Overlay 12CO contours ontop of continuum map

# %%
mom0_12CO = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/data/DraChi.briggs0.12CO.LSRK.im.image_M0.fits')

# %%
color_table='cubehelix'
fig = plt.figure(dpi=150)

f_cont = aplpy.FITSFigure(cont, figure=fig, dimensions=[0,1], slices=[1])
fix_aplpy_fits(f_cont)

vmin, vmax = np.nanpercentile(cont[0].data, [2,98])
f_cont.show_colorscale(cmap=color_table) 

# adopt the default layout
figure_layout( f_cont, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False)

rms_em = 2.41e2 # Jy/beam from CASA
c_levs = np.array([3, 6, 12, 24])*rms_em
f_cont.show_contour(mom0_12CO, colors='white', linewidths=2., levels=c_levs)
f_cont.show_contour(mom0_12CO, colors='black', linewidths=1., levels=c_levs)

# got the coordinates of the center from CASAviewer
f_cont.recenter(347.432,67.3942,width=0.008,height=0.008)

f_cont.add_label(0.80,0.92, '$^{12}$CO $(2-1)$', relative=True, color='white', size=20)


im = plt.imshow(cont[0].data[0][0]*1000, cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('Flux density $(\mathrm{mJy\,beam^{-1}})$', fontsize=10)

fig.savefig('../plots/DraChi_cont_12COcontours.pdf', bbox_inches='tight')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.248e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.084e-02 [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
color_table='cubehelix'
fig = plt.figure(dpi=150)

f_cont = aplpy.FITSFigure(cont, figure=fig, dimensions=[0,1], slices=[1])
fix_aplpy_fits(f_cont)

vmin, vmax = np.nanpercentile(cont[0].data, [2,98])
f_cont.show_colorscale(cmap=color_table) 

# adopt the default layout
figure_layout( f_cont, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False)

rms_em = 1.41e-3 # Jy/beam from CASA
c_levs = np.array([3,6,12,24,48])*rms_em
f_cont.show_contour(colors='white', linewidths=2, levels=c_levs)
f_cont.show_contour(colors='black', linewidths=1, levels=c_levs)

rms_em = 2.41e2 # Jy/beam from CASA
c_levs = np.array([3,6,12,24,48])*rms_em
f_cont.show_contour(mom0_12CO, colors='white', linewidths=2, levels=c_levs)
f_cont.show_contour(mom0_12CO, colors='magenta', linewidths=1, levels=c_levs)

# got the coordinates of the center from CASAviewer
f_cont.recenter(347.432,67.3942,width=0.008,height=0.008)

f_cont.add_label(0.17,0.92, '1.3mm', relative=True, color='black', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])
f_cont.add_label(0.12,0.82, '$^{12}$CO', relative=True, color='white', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="black")])


im = plt.imshow(cont[0].data[0][0]*1000, cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('Flux density $(\mathrm{mJy\,beam^{-1}})$', fontsize=10)

fig.savefig('../plots/DraChi_cont_12COandcontinuumcontours.pdf', bbox_inches='tight')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.177e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.036e-02 [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
color_table='cubehelix'
fig = plt.figure(dpi=150)

f_cont = aplpy.FITSFigure(cont, figure=fig, dimensions=[0,1], slices=[1])
fix_aplpy_fits(f_cont)

vmin, vmax = np.nanpercentile(cont[0].data, [2,98])
f_cont.show_colorscale(cmap=color_table) 

# adopt the default layout
figure_layout( f_cont, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False)

max_em = 0.016 # Jy/beam from CASA
c_levs = np.arange(0.1,1.2,0.2)*max_em
f_cont.show_contour(colors='black', linewidths=1.5, levels=c_levs)

max_em = 1.05e4 # mJy/beam m/s from mom0 map
c_levs = np.arange(0.1,1.2,0.2)*max_em
f_cont.show_contour(mom0_12CO, colors='white', linewidths=1.5, levels=c_levs, alpha=0.8)


# got the coordinates of the center from CASAviewer
f_cont.recenter(347.432,67.3942,width=0.008,height=0.008)

f_cont.add_label(0.17,0.92, '1.3mm', relative=True, color='black', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])
f_cont.add_label(0.12,0.82, '$^{12}$CO', relative=True, color='white', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="black")])


im = plt.imshow(cont[0].data[0][0]*1000, cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('Flux density $(\mathrm{mJy\,beam^{-1}})$', fontsize=10)

fig.savefig('../plots/DraChi_cont_12COandcontinuumcontours_2.pdf', bbox_inches='tight')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.266e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.048e-02 [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
color_table='cubehelix'
fig = plt.figure(dpi=150)

max_12CO = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/data/not_clipped/DraChi.briggs0.12CO.LSRK.im.image_Fnu.fits')

f_cont = aplpy.FITSFigure(cont, figure=fig, dimensions=[0,1], slices=[1])
fix_aplpy_fits(f_cont)

vmin, vmax = np.nanpercentile(cont[0].data, [2,98])
f_cont.show_colorscale(cmap=color_table) 

# adopt the default layout
figure_layout( f_cont, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False)

max_em = 0.016 # Jy/beam from CASA
c_levs = np.arange(0.1,1.2,0.2)*max_em
f_cont.show_contour(colors='black', linewidths=1.5, levels=c_levs)

max_em = 3.55 # mJy/beam m/s from mom0 map
c_levs = np.arange(0.1,1.2,0.2)*max_em
f_cont.show_contour(max_12CO, colors='white', linewidths=1.5, levels=c_levs, alpha=0.8)


# got the coordinates of the center from CASAviewer
f_cont.recenter(347.432,67.3942,width=0.008,height=0.008)

f_cont.add_label(0.17,0.92, '1.3mm', relative=True, color='black', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])
f_cont.add_label(0.12,0.82, '$^{12}$CO', relative=True, color='white', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="black")])


im = plt.imshow(cont[0].data[0][0]*1000, cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('Flux density $(\mathrm{mJy\,beam^{-1}})$', fontsize=10)

fig.savefig('../plots/DraChi_cont_12COandcontinuumcontours_3.pdf', bbox_inches='tight')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.254e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.045e-02 [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
import cmocean
color_table=cmocean.cm.curl
fig = plt.figure(dpi=150)

max_12CO = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/data/not_clipped/DraChi.briggs0.12CO.LSRK.im.image_Fnu.fits')

f_cont = aplpy.FITSFigure(cont, figure=fig, dimensions=[0,1], slices=[1])
fix_aplpy_fits(f_cont)

vmin, vmax = np.nanpercentile(cont[0].data, [2,98])
f_cont.show_colorscale(cmap=color_table) 

# adopt the default layout
figure_layout( f_cont, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False)

rms = 17.
c_levs = np.array([4, 16, 40, 160, 400, 1600])*rms
f_cont.show_contour('/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.g.unconv.fits', colors='white', linewidths=2., levels=c_levs, smooth=3, kernel='box')
f_cont.show_contour('/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.g.unconv.fits', colors='black', linewidths=1., levels=c_levs, smooth=3, kernel='box')


# got the coordinates of the center from CASAviewer
f_cont.recenter(347.432,67.3942,width=0.008,height=0.008)

im = plt.imshow(cont[0].data[0][0]*1000, cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('Flux density $(\mathrm{mJy\,beam^{-1}})$', fontsize=10)

#fig.savefig('../plots/DraChi_cont_12COandcontinuumcontours_3.pdf', bbox_inches='tight')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.107e-03 [aplpy.core]
# INFO: Auto-setting vmax to  9.837e-03 [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-04-29T14:17:06.999' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-04-29T14:17:06.999' from MJD-OBS'. [astropy.wcs.wcs]

# %%
color_table='cubehelix'
fig = plt.figure(dpi=150)

f_max_12CO = aplpy.FITSFigure(max_12CO, figure=fig)#, slices=[0],

vmin, vmax = np.nanpercentile(max_12CO[0].data, [2, 98])
f_max_12CO.show_colorscale(cmap=color_table, vmax=10000) 


# adopt the default layout
figure_layout( f_max_12CO, c_unit='(Jy beam$^{-1}$ m s$^{-1}$)', colorbar=False, fontcolor='white')

rms = 17.
c_levs = np.array([4, 16, 40, 160, 400, 1600])*rms
f_max_12CO.show_contour('/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.g.unconv.fits', colors='white', linewidths=2., levels=c_levs, smooth=3, kernel='box')
f_max_12CO.show_contour('/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.g.unconv.fits', colors='black', linewidths=1., levels=c_levs, smooth=3, kernel='box')

# got the coordinates of the center from CASAviewer
f_max_12CO.recenter(347.432,67.3942,width=0.008,height=0.008)

f_max_12CO.add_label(0.75,0.92, '$^{12}$CO $(2-1)$', relative=True, color='white', size=20)


im = plt.imshow(max_12CO[0].data/1000., cmap=color_table)
cb_ax = fig.add_axes([0.81, 0.11, 0.01, 0.772]) #right, top, thickness, length
cbar = fig.colorbar(im, cax=cb_ax)
cbar.set_label('$(\mathrm{Jy\,beam^{-1}\,km\,s^{-1}})$', fontsize=10)

#fig.savefig('../plots/DraChi_max_12CO_withcontours_2.pdf', bbox_inches='tight')
