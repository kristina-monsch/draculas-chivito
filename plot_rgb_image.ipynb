# %%
import matplotlib.pylab as plt
import numpy as np
from astropy import units as u
from astropy.io import fits
import aplpy
import matplotlib.patheffects as pe

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
aplpy.make_rgb_cube(['/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.i.unconv.fits', 
                     '/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.r.unconv.fits',
                     '/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.g.unconv.fits'], 
                    'DraChi_RGB_cube.fits')
# Out:
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-06-14T17:23:33.434' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-07-15T03:19:01.863' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-04-29T14:17:06.999' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-06-14T17:23:33.434' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-07-15T03:19:01.863' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-04-29T14:17:06.999' from MJD-OBS'. [astropy.wcs.wcs]

# %%
aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=1e5, vmax_g=1e5, vmax_b=5e4)

f = aplpy.FITSFigure('DraChi_rgb.png')
f.show_rgb()

plt.xlabel('Right Ascension (ICRS)', fontsize=20)
plt.ylabel('Declination (ICRS)', fontsize=20)

#plt.(fontsize=20)
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...

# %%
fig = plt.figure(dpi=300)

aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=2e5, vmax_g=1e5, vmax_b=5e4)

f = aplpy.FITSFigure('DraChi_rgb.png', figure=fig)
f.show_rgb()

f.axis_labels.set_font(size=15)
f.axis_labels.set_xtext('Right Ascension (ICRS)')
f.axis_labels.set_ytext('Declination (ICRS)')
f.axis_labels.set_ypad(pad=-1.5)


f.tick_labels.set_font(size=12)
#f.tick_labels.set_xformat('d.dd')
#f.tick_labels.set_yformat('d.ddd')

ang_sep = (12*u.arcsec).to(u.rad)
f.add_scalebar(ang_sep)
f.scalebar.set_label("$12''$")
f.scalebar.set_font(size=22)
f.scalebar.set_linewidth(4)
f.scalebar.set_color('white')

f.ticks.set_color('white')
f.ticks.set_tick_direction('in')
f.ticks.set_minor_frequency(4)
#f.ticks.set_xspacing(0.008)  # degrees
f.ticks.set_yspacing(0.006)  # degrees

f.add_label(0.095,0.15, 'red: $i$', relative=True, color='red', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.13,0.10, 'green: $r$', relative=True, color='green', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.115,0.05, 'blue: $g$', relative=True, color='blue', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])

f.add_grid()
f.grid.set_color('white')
f.grid.set_alpha(0.5)
f.grid.set_linestyle(':')



fig.savefig('../plots/DraChi_irg.pdf', bbox_inches='tight')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  2.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...

# %%
fig = plt.figure(dpi=300)

aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=2e5, vmax_g=1e5, vmax_b=5e4)

f = aplpy.FITSFigure('DraChi_rgb.png', figure=fig)
f.show_rgb()

f.axis_labels.set_font(size=15)
f.axis_labels.set_xtext('Right Ascension (ICRS)')
f.axis_labels.set_ytext('Declination (ICRS)')
f.axis_labels.set_ypad(pad=-1.5)


f.tick_labels.set_font(size=12)
#f.tick_labels.set_xformat('d.dd')
#f.tick_labels.set_yformat('d.ddd')

ang_sep = (12*u.arcsec).to(u.rad)
f.add_scalebar(ang_sep)
f.scalebar.set_label("$12''$")
f.scalebar.set_font(size=22)
f.scalebar.set_linewidth(4)
f.scalebar.set_color('white')

f.ticks.set_color('white')
f.ticks.set_tick_direction('in')
f.ticks.set_minor_frequency(4)
#f.ticks.set_xspacing(0.008)  # degrees
f.ticks.set_yspacing(0.006)  # degrees

rms = 17.
c_levs = np.array([4, 16, 40, 160, 400, 1600])*rms
f.show_contour('/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.g.unconv.fits', colors='white', linewidths=2., levels=c_levs, smooth=3, kernel='box')
f.show_contour('/Users/kristina/Hamburgers/Draculas_Chivito/Pan-STARRS_fits_files/cutout_rings.v3.skycell.2537.088.stk.g.unconv.fits', colors='black', linewidths=1., levels=c_levs, smooth=3, kernel='box')

f.add_label(0.095,0.15, 'red: $i$', relative=True, color='red', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.13,0.10, 'green: $r$', relative=True, color='green', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.115,0.05, 'blue: $g$', relative=True, color='blue', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])



fig.savefig('../plots/DraChi_irg_withcontours.pdf', bbox_inches='tight')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  2.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-04-29T14:17:06.999' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-04-29T14:17:06.999' from MJD-OBS'. [astropy.wcs.wcs]

# %%
fig = plt.figure(dpi=300)

aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=2e5, vmax_g=1e5, vmax_b=5e4)

mom0_12CO = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/data/DraChi.briggs0.12CO.LSRK.im.image_M0.fits')

f = aplpy.FITSFigure('DraChi_rgb.png', figure=fig)
f.show_rgb()

f.axis_labels.set_font(size=15)
f.axis_labels.set_xtext('Right Ascension (ICRS)')
f.axis_labels.set_ytext('Declination (ICRS)')
f.axis_labels.set_ypad(pad=-1.5)


f.tick_labels.set_font(size=12)
#f.tick_labels.set_xformat('d.dd')
#f.tick_labels.set_yformat('d.ddd')

ang_sep = (12*u.arcsec).to(u.rad)
f.add_scalebar(ang_sep)
f.scalebar.set_label("$12''$")
f.scalebar.set_font(size=22)
f.scalebar.set_linewidth(4)
f.scalebar.set_color('white')

f.ticks.set_color('white')
f.ticks.set_tick_direction('in')
f.ticks.set_minor_frequency(4)
#f.ticks.set_xspacing(0.008)  # degrees
f.ticks.set_yspacing(0.006)  # degrees

#rms = 9.93e-02 # obtained from bettermoments, see above
rms = 2.41e2
c_levs = np.array([3,6,12,24])*rms

f.show_contour(mom0_12CO, colors='white', linewidths=2, levels=c_levs)
f.show_contour(mom0_12CO, colors='black', linewidths=1, levels=c_levs)

#, levels=c_levs)

f.add_label(0.095,0.15, 'red: $i$', relative=True, color='red', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.13,0.10, 'green: $r$', relative=True, color='green', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.115,0.05, 'blue: $g$', relative=True, color='blue', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])



fig.savefig('../plots/DraChi_irg_withSMAcontours.pdf', bbox_inches='tight')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  2.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...

# %%
fig = plt.figure(dpi=300)

aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=2e5, vmax_g=1e5, vmax_b=5e4)

max_12CO = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/DraChi.briggs0.12CO.LSRK.im.image_Fnu.fits')

f = aplpy.FITSFigure('DraChi_rgb.png', figure=fig)
f.show_rgb()

f.axis_labels.set_font(size=15)
f.axis_labels.set_xtext('Right Ascension (ICRS)')
f.axis_labels.set_ytext('Declination (ICRS)')
f.axis_labels.set_ypad(pad=-1.5)


f.tick_labels.set_font(size=12)
#f.tick_labels.set_xformat('d.dd')
#f.tick_labels.set_yformat('d.ddd')

ang_sep = (12*u.arcsec).to(u.rad)
f.add_scalebar(ang_sep)
f.scalebar.set_label("$12''$")
f.scalebar.set_font(size=22)
f.scalebar.set_linewidth(4)
f.scalebar.set_color('white')

f.ticks.set_color('white')
f.ticks.set_tick_direction('in')
f.ticks.set_minor_frequency(4)
#f.ticks.set_xspacing(0.008)  # degrees
f.ticks.set_yspacing(0.006)  # degrees


max_em = 3.55 # mJy/beam m/s from mom0 map
c_levs = np.arange(0.1,1.2,0.2)*max_em
f.show_contour(max_12CO, colors='white', linewidths=2., levels=c_levs, alpha=0.8)
f.show_contour(max_12CO, colors='black', linewidths=1., levels=c_levs, alpha=0.8)

#f.add_label(0.17,0.92, '1.3mm', relative=True, color='black', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])
f.add_label(0.12,0.92, '$^{12}$CO', relative=True, color='white', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="black")])


#, levels=c_levs)

f.add_label(0.095,0.15, 'red: $i$', relative=True, color='red', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.13,0.10, 'green: $r$', relative=True, color='green', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.115,0.05, 'blue: $g$', relative=True, color='blue', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])



#fig.savefig('../plots/DraChi_irg_withSMAcontours.pdf', bbox_inches='tight')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  2.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...

# %% [markdown]
# #### Modify the header of the continuum file to remove the 3rd and 4th axes, because this causes issues when plotting the contours, cf. https://github.com/aplpy/aplpy/issues/449

# %%
cont = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/data/DraChi.CONT_modified_header.fits')  # open a FITS file

# %%
del cont[0].header['NAXIS3']
del cont[0].header['NAXIS4']

# %%
cont[0].header['NAXIS'] = 2

# %%
del cont[0].header['CTYPE3']
del cont[0].header['CRVAL3']
del cont[0].header['CDELT3']
del cont[0].header['CRPIX3']
del cont[0].header['CUNIT3']

del cont[0].header['CTYPE4']
del cont[0].header['CRVAL4']
del cont[0].header['CDELT4']
del cont[0].header['CRPIX4']
del cont[0].header['CUNIT4']

# %%
del cont[0].header['PC3_1']  
del cont[0].header['PC4_1']  
del cont[0].header['PC3_2']  
del cont[0].header['PC4_2']  
del cont[0].header['PC3_3']  
del cont[0].header['PC4_3']  
del cont[0].header['PC3_4']  
del cont[0].header['PC4_4']

# %%
del cont[0].header['PC1_3']  
del cont[0].header['PC1_4']  
del cont[0].header['PC2_3']  
del cont[0].header['PC2_4']

# %%
cont[0].header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    2
# NAXIS1  =                  144
# NAXIS2  =                  144
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   1.013391282823E-03
# BMIN    =   6.732167800268E-04
# BPA     =   2.296761894226E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'DraChi  '
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =   6.739415000000E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   3.474318541667E+02
# CDELT1  =  -1.388888888889E-04
# CRPIX1  =   7.300000000000E+01
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =   6.739415000000E+01
# CDELT2  =   1.388888888889E-04
# CRPIX2  =   7.300000000000E+01
# CUNIT2  = 'deg     '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   2.255264159921E+11 /Rest Frequency (Hz)
# SPECSYS = 'LSRK    '           /Spectral reference frame
# ALTRVAL =  -0.000000000000E+00 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'SMA     '
# OBSERVER= 'SMA     '
# DATE-OBS= '2023-04-25T13:41:14.229173'
# TIMESYS = 'UTC     '
# OBSRA   =   3.474318541667E+02
# OBSDEC  =   6.739415000000E+01
# OBSGEO-X=  -5.462448949395E+06
# OBSGEO-Y=  -2.491969916598E+06
# OBSGEO-Z=   2.164446105480E+06
# INSTRUME= 'SMA     '
# DISTANCE=   0.000000000000E+00
# MPIPROCS=                    1
# CHNCHNKS=                    1
# MEMREQ  =        1.0862947E-03
# MEMAVAIL=        7.9611244E+01
# USEWEIGH=                    F
# DATE    = '2023-07-20T18:29:51.440659' /Date FITS file was written
# ORIGIN  = 'CASA 6.4.1-12 CASAtools:v1.0.0'
# HISTORY CASA START LOGTABLE
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY taskname=tclean
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY version: 6.5.3-28 CASAtools:v1.0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY vis         = "DraChi.redux.cont.ms/"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY selectdata  = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY field       = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY spw         = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY timerange   = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY uvrange     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY antenna     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY scan        = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY observation = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY intent      = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY datacolumn  = "corrected"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY imagename   = "DraChi.2305redux.briggs.im"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY imsize      = 144
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cell        = "0.5arcsec"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY phasecenter = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY stokes      = "I"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY projection  = "SIN"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY startmodel  = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY specmode    = "mfs"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY reffreq     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nchan       = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY start       = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY width       = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY outframe    = "LSRK"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY veltype     = "radio"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restfreq    = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY interpolation = "linear"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY perchanweightdensity = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY gridder     = "standard"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY facets      = 1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY psfphasecenter = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY wprojplanes = 1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY vptable     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY mosweight   = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY aterm       = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY psterm      = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY wbawp       = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY conjbeams   = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cfcache     = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY usepointing = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY computepastep = 360.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY rotatepastep = 360.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pointingoffsetsigdev = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pblimit     = 0.2
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY normtype    = "flatnoise"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY deconvolver = "hogbom"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY scales      = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nterms      = 2
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY smallscalebias = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY fusedthreshold = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY largestscale = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restoration = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restoringbeam = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pbcor       = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY outlierfile = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY weighting   = "briggs"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY robust      = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY noise       = "1.0Jy"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY npixels     = 0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY uvtaper     = []
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY niter       = 1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY gain        = 0.1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY threshold   = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nsigma      = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cycleniter  = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cyclefactor = 1.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY minpsffraction = 0.05
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY maxpsffraction = 0.8
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY interactive = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY fullsummary = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY nmajor      = -1
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY usemask     = "user"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY mask        = ""
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY pbmask      = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY sidelobethreshold = 3.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY noisethreshold = 5.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY lownoisethreshold = 1.5
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY negativethreshold = 0.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY smoothfactor = 1.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY minbeamfrac = 0.3
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY cutthreshold = 0.01
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY growiterations = 75
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY dogrowprune = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY minpercentchange = -1.0
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY verbose     = False
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY fastnoise   = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY restart     = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY savemodel   = "none"
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY calcres     = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY calcpsf     = True
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY psfcutoff   = 0.35
# HISTORY 2023-05-26T12:37:23 INFO SRCCODE='::tclean'
# HISTORY parallel    = False
# HISTORY CASA END LOGTABLE

# %%
fig = plt.figure(dpi=300)

aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=2e5, vmax_g=1e5, vmax_b=5e4)

f = aplpy.FITSFigure('DraChi_rgb.png', figure=fig)
f.show_rgb()

f.axis_labels.set_font(size=15)
f.axis_labels.set_xtext('Right Ascension (ICRS)')
f.axis_labels.set_ytext('Declination (ICRS)')
f.axis_labels.set_ypad(pad=-1.5)


f.tick_labels.set_font(size=12)
#f.tick_labels.set_xformat('d.dd')
#f.tick_labels.set_yformat('d.ddd')

ang_sep = (12*u.arcsec).to(u.rad)
f.add_scalebar(ang_sep)
f.scalebar.set_label("$12''$")
f.scalebar.set_font(size=22)
f.scalebar.set_linewidth(4)
f.scalebar.set_color('white')

f.ticks.set_color('white')
f.ticks.set_tick_direction('in')
f.ticks.set_minor_frequency(4)
#f.ticks.set_xspacing(0.008)  # degrees
f.ticks.set_yspacing(0.006)  # degrees

max_em = 0.016 # Jy/beam from CASA
c_levs = np.arange(0.2,1.2,0.2)*max_em

f.show_contour(cont, colors='white', linewidths=2, levels=c_levs)
f.show_contour(cont, colors='black', linewidths=1, levels=c_levs)
f.add_label(0.17,0.92, '1.3mm', relative=True, color='black', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])


#, levels=c_levs)

f.add_label(0.095,0.15, 'red: $i$', relative=True, color='red', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.13,0.10, 'green: $r$', relative=True, color='green', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.115,0.05, 'blue: $g$', relative=True, color='blue', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])



fig.savefig('../plots/DraChi_irg_withSMAcontours_continuum.pdf', bbox_inches='tight')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  2.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
fig = plt.figure(dpi=300)

aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=2e5, vmax_g=1e5, vmax_b=5e4)

f = aplpy.FITSFigure('DraChi_rgb.png', figure=fig)
f.show_rgb()

f.axis_labels.set_font(size=15)
f.axis_labels.set_xtext('Right Ascension (ICRS)')
f.axis_labels.set_ytext('Declination (ICRS)')
f.axis_labels.set_ypad(pad=-1.5)


f.tick_labels.set_font(size=12)
#f.tick_labels.set_xformat('d.dd')
#f.tick_labels.set_yformat('d.ddd')

ang_sep = (12*u.arcsec).to(u.rad)
f.add_scalebar(ang_sep)
f.scalebar.set_label("$12''$")
f.scalebar.set_font(size=22)
f.scalebar.set_linewidth(4)
f.scalebar.set_color('white')

f.ticks.set_color('white')
f.ticks.set_tick_direction('in')
f.ticks.set_minor_frequency(4)
#f.ticks.set_xspacing(0.008)  # degrees
f.ticks.set_yspacing(0.006)  # degrees

max_em = 0.016 # Jy/beam from CASA
c_levs = np.arange(0.1,1.2,0.2)*max_em
f.show_contour(cont, colors='white', linewidths=2, levels=c_levs)
f.show_contour(cont, colors='black', linewidths=1, levels=c_levs)
f.add_label(0.17,0.92, '1.3mm', relative=True, color='black', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])


rms = 2.41e2
c_levs = np.array([3,6,12,24])*rms
#f.show_contour(mom0_12CO, colors='pink', linewidths=2, levels=c_levs)
#f.show_contour(mom0_12CO, colors='black', linewidths=1, levels=c_levs)
#f.add_label(0.17,0.72, '$^{12}$CO', relative=True, color='pink', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])


#, levels=c_levs)

f.add_label(0.095,0.15, 'red: $i$', relative=True, color='red', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.13,0.10, 'green: $r$', relative=True, color='green', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.115,0.05, 'blue: $g$', relative=True, color='blue', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])



fig.savefig('../plots/DraChi_irg_withSMAcontours_continuum_2.pdf', bbox_inches='tight')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  2.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
fig = plt.figure(dpi=300)

aplpy.make_rgb_image('DraChi_RGB_cube.fits','DraChi_rgb.png', 
                     stretch_r='log', stretch_g='log', stretch_b='log',
                     vmin_r=0., vmin_g=0., vmin_b=0.,
                     vmax_r=2e5, vmax_g=1e5, vmax_b=5e4)

f = aplpy.FITSFigure('DraChi_rgb.png', figure=fig)
f.show_rgb()

f.axis_labels.set_font(size=15)
f.axis_labels.set_xtext('Right Ascension (ICRS)')
f.axis_labels.set_ytext('Declination (ICRS)')
f.axis_labels.set_ypad(pad=-1.5)


f.tick_labels.set_font(size=12)
#f.tick_labels.set_xformat('d.dd')
#f.tick_labels.set_yformat('d.ddd')

ang_sep = (12*u.arcsec).to(u.rad)
f.add_scalebar(ang_sep)
f.scalebar.set_label("$12''$")
f.scalebar.set_font(size=22)
f.scalebar.set_linewidth(4)
f.scalebar.set_color('white')

f.ticks.set_color('white')
f.ticks.set_tick_direction('in')
f.ticks.set_minor_frequency(4)
#f.ticks.set_xspacing(0.008)  # degrees
f.ticks.set_yspacing(0.006)  # degrees

max_em = 0.016 # Jy/beam from CASA
c_levs = np.arange(0.1,1.2,0.2)*max_em
f.show_contour(cont, colors='white', linewidths=2, levels=c_levs)
f.show_contour(cont, colors='black', linewidths=1, levels=c_levs)
f.add_label(0.17,0.92, '1.3mm', relative=True, color='black', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])


max_em = 1.05e4 # mJy/beam m/s from mom0 map
c_levs = np.arange(0.1,1.2,0.2)*max_em
f.show_contour(mom0_12CO, colors='white', linewidths=2, levels=c_levs)
f.show_contour(mom0_12CO, colors='magenta', linewidths=1, levels=c_levs)
f.add_label(0.13,0.82, '$^{12}$CO', relative=True, color='magenta', size=20, path_effects=[pe.withStroke(linewidth=1., foreground="white")])


#, levels=c_levs)

f.add_label(0.095,0.15, 'red: $i$', relative=True, color='red', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.13,0.10, 'green: $r$', relative=True, color='green', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])
f.add_label(0.115,0.05, 'blue: $g$', relative=True, color='blue', size=12, weight='semibold', path_effects=[pe.withStroke(linewidth=1.5, foreground="white")])



fig.savefig('../plots/DraChi_irg_withSMAcontours_continuum_and_12CO.pdf', bbox_inches='tight')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  2.000e+05 [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  1.000e+05 [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  0.000e+00 [aplpy.rgb]
# INFO: vmax =  5.000e+04 [aplpy.rgb]
# b'<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:avm="http://www.communicatingastronomy.org/avm/1.0/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:x="adobe:ns:meta/"><rdf:RDF><rdf:Description><avm:MetadataVersion>1.1000000000000001</avm:MetadataVersion><avm:Spatial.CoordinateFrame>ICRS</avm:Spatial.CoordinateFrame><avm:Spatial.Equinox>nan</avm:Spatial.Equinox><avm:Spatial.ReferenceValue><rdf:Bag><rdf:li>350.7692083690000118</rdf:li><rdf:li>65.9999966182350022</rdf:li></rdf:Bag></avm:Spatial.ReferenceValue><avm:Spatial.ReferenceDimension><rdf:Bag><rdf:li>160.0000000000000000</rdf:li><rdf:li>160.0000000000000000</rdf:li></rdf:Bag></avm:Spatial.ReferenceDimension><avm:Spatial.ReferencePixel><rdf:Bag><rdf:li>-18391.5044421800012060</rdf:li><rdf:li>-20495.9959792480003671</rdf:li></rdf:Bag></avm:Spatial.ReferencePixel><avm:Spatial.Scale><rdf:Bag><rdf:li>-0.0000694444461260</rdf:li><rdf:li>0.0000694444461260</rdf:li></rdf:Bag></avm:Spatial.Scale><avm:Spatial.Rotation>0.0000000000000000</avm:Spatial.Rotation><avm:Spatial.CoordsystemProjection>TAN</avm:Spatial.CoordsystemProjection><avm:Spatial.Quality>Full</avm:Spatial.Quality><avm:Spatial.FITSheader>SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                  -32 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  160                                                  NAXIS2  =                  160                                                  WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =      -18391.50444218 / Pixel coordinate of reference point            CRPIX2  =     -20495.995979248 / Pixel coordinate of reference point            CDELT1  = -6.9444446125999E-05 / [deg] Coordinate increment at reference point  CDELT2  =  6.9444446125999E-05 / [deg] Coordinate increment at reference point  CUNIT1  = \'deg\'                / Units of coordinate increment and value        CUNIT2  = \'deg\'                / Units of coordinate increment and value        CTYPE1  = \'RA---TAN\'           / Right ascension, gnomonic projection           CTYPE2  = \'DEC--TAN\'           / Declination, gnomonic projection               CRVAL1  =        350.769208369 / [deg] Coordinate value at reference point      CRVAL2  =      65.999996618235 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =      65.999996618235 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = \'ICRS\'               / Equatorial coordinate system                   END                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60059.570304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -155.477522 from OBSGEO-[XYZ].
# Set OBSGEO-B to    19.947177 from OBSGEO-[XYZ].
# Set OBSGEO-H to     6578.484 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
mom0_12CO = fits.open('/Users/kristina/Hamburgers/Draculas_Chivito/SMA/data/DraChi.briggs0.12CO.LSRK.im.image_M0.fits')
mom0_12CO[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  144
# NAXIS2  =                  144
# BMAJ    = 0.001078328424029880
# BMIN    = 0.000693414211273193
# BPA     =            20.496504
# BUNIT   = 'Jy/beam m/s'
# CTYPE1  = 'RA---SIN'
# CRVAL1  =       347.4318541667
# CDELT1  =  -0.0001388888888889
# CRPIX1  =                 73.0
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =             67.39415
# CDELT2  =   0.0001388888888889
# CRPIX2  =                 73.0
# CUNIT2  = 'deg     '
# RESTFRQ =       230538000000.0
# SPECSYS = 'LSRK    '
# EQUINOX =               2000.0
# COMMENT made with bettermoments
